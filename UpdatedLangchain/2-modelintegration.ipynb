# %% [markdown]
# ### Models Integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model(model="gpt-5")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-5', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high']}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000230ABAF3D90>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000230ABD84190>, root_client=<openai.OpenAI object at 0x00000230ABAF3890>, root_async_client=<openai.AsyncOpenAI object at 0x00000230ABAF3ED0>, model_name='gpt-5', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
## Invoke the model
response=model.invoke("Hello there! How are you?")
response
# Out:
# AIMessage(content='Hi! I’m doing well, thanks for asking. How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 13, 'total_tokens': 104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EMtxjXNbxkDppakgaXUoTR9zN5tKc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09048-21e6-7303-8b67-79fcaa0235c3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 91, 'total_tokens': 104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})

# %%
response.content
# Out:
# 'Hi! I’m doing well, thanks for asking. How can I help you today?'

# %%
## Google gemini Model Integration
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "google_genai:gemini-3.5-flash-lite",
    temperature=0
)

response = model.invoke("Hello there! How are you?")

print(response.content)
# Out:
# c:\Users\kajal\OneDrive\Dokumen\Langchain Updated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text', 'text': "Hello! I'm doing well, thank you for asking. How are you doing today? How can I help you?", 'extras': {'signature': 'El4KXAERTTIPvbgC80807Gfxi7cnhXP9WmXfBs6BkDG72yCspzdtKyV2OKQN8K/Bq8jgBXyIv+fFhZI9O6A6wQKZzpcVnE2Fjwl9XpLaKOqeOibBKg4g0CLlmyUQtyv7'}}]

# %%
response.text
# Out:
# "Hello! I'm doing well, thank you for asking. How are you doing today? How can I help you?"

# %%
##ChatOpenAI Model Integration
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello there! How are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you with whatever you need. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 14, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_5d7905adfb', 'id': 'chatcmpl-EMuCa0uNiCCSsNj4mmyy2w5OLiCqv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09056-23c0-7ca2-b7ec-3e3d42f2fcc4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 34, 'total_tokens': 48, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you with whatever you need. How can I assist you today?"

# %%
## Groq Model Integration

model = init_chat_model(
    "groq:openai/gpt-oss-20b"
)
response = model.invoke("Hello there! How are you?")
response
# Out:
# AIMessage(content='Hello! I’m doing great—thanks for asking. How about you? 🚀', additional_kwargs={'reasoning_content': 'The user says "Hello there! How are you?" It\'s a greeting. The user wants a friendly response. According to the policies, we can respond in a friendly manner. There\'s no conflict. Just respond politely.'}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 78, 'total_tokens': 148, 'completion_time': 0.091467095, 'completion_tokens_details': {'reasoning_tokens': 44}, 'prompt_time': 0.004017323, 'prompt_tokens_details': None, 'queue_time': 0.416161374, 'total_time': 0.095484418}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_5979a0e1b7', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a09059-6b48-7880-9014-084fb8865a84-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 78, 'output_tokens': 70, 'total_tokens': 148, 'output_token_details': {'reasoning': 44}})

# %%
response.content
# Out:
# 'Hello! I’m doing great—thanks for asking. How about you? 🚀'
